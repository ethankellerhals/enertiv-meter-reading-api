# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np
from imutils.perspective import four_point_transform
from imutils import contours
import imutils


import numpy as np

# %%
img = Image.open("temp_dataset/segmentation/00882400318057_0_Meter_0.jpg")
img = Image.open("temp_dataset/segmentation/00880000075276_0_2.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=282x44>

# %%
pytesseract.image_to_string(img)
# Out:
# ''

# %%
pytesseract.image_to_string(img, lang='eng', config='--psm 10 -c tessedit_char_whitelist=0123456789')
# Out:
# '14804\n'

# %%
Image.open("temp_dataset/segmentation/image.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=106x43>

# %%
# load the image, convert it to grayscale, and blur it to remove noise
image = cv2.imread("temp_dataset/segmentation/image.png")
image = cv2.imread("temp_dataset/segmentation/00880000075276_0_2.jpg")
image = cv2.imread("temp_dataset/segmentation/00450000100512_0.jpg")

# sharpen_filter=np.array([[-1,-1,-1],
#                  [-1,9,-1],
#                 [-1,-1,-1]])
# # applying kernels to the input image to get the sharpened image
# sharp_image=cv2.filter2D(image,-1,sharpen_filter)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#gray = cv2.GaussianBlur(gray, (5, 5), 0)
#gray = cv2.GaussianBlur(gray, (7, 7), 0)

# threshold the image
ret,th1 = cv2.threshold(gray ,127,255,cv2.THRESH_BINARY_INV)
th2 = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
# dilate the white portions
#dilate = cv2.dilate(thresh1, None, iterations=2)


plt.imshow(th1, cmap='gray')
plt.show()
plt.imshow(th2, cmap='gray')
#pytesseract.image_to_string(thresh1)

pytesseract.image_to_string(image, lang='eng', config='--psm 10 -c tessedit_char_whitelist=0123456789')
pytesseract.image_to_string(th1, lang='eng', config='--psm 10 --oem 3 -c tessedit_char_whitelist=0123456789')
# Out:
# '29310488\n'

# %%
original_image=cv2.imread("temp_dataset/segmentation/00450000100512_0.jpg")
# create a sharpening kernel
sharpen_filter=np.array([[-1,-1,-1],
                 [-1,9,-1],
                [-1,-1,-1]])
# applying kernels to the input image to get the sharpened image
sharp_image=cv2.filter2D(original_image,-1,sharpen_filter)
plt.imshow(sharp_image)
plt.show()
pytesseract.image_to_string(sharp_image, lang='eng', config='--psm 10 --oem 3 -c tessedit_char_whitelist=0123456789')
# Out:
# '9300488\n'

# %%
import cv2
import pytesseract

# Load the image
img = cv2.imread('temp_dataset/segmentation/00450000100512_0.jpg')

# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply thresholding to the image
threshold_img = cv2.threshold(gray_img, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]

# Apply dilation to the image
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
dilation_img = cv2.dilate(threshold_img, kernel, iterations=1)

# Apply OCR to the image
text = pytesseract.image_to_string(dilation_img, config='--psm 11')

# Display the result
plt.imshow(threshold_img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 21
#      18 text = pytesseract.image_to_string(dilation_img, config='--psm 11')
#      20 # Display the result
# ---> 21 plt.imshow(threshold_img)
#      22 plt.show()
#
# NameError: name 'plt' is not defined

# %%
img = result
# Define the color range to keep
lower = np.array([0, 0, 0])
upper = np.array([0, 0, 0])

# Create a mask of the pixels within the color range
mask = cv2.inRange(img, lower, upper)

# Invert the mask
mask_inv = cv2.bitwise_not(mask)

# Create a white background image
white_bg = np.full_like(img, (255, 255, 255))

# Apply the mask to the original image and the white background
result = cv2.bitwise_or(img, img, mask=mask_inv)
result = cv2.bitwise_or(result, white_bg, mask=mask)

plt.imshow(result)
plt.show()

# %%
pytesseract.image_to_string()
# Out:
# ''
